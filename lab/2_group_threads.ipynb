# %%
import pandas as pd

# %%
df = pd.read_csv('emails2.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        130 non-null    object
#  1   threadId  130 non-null    object
#  2   snippet   130 non-null    object
#  3   body      110 non-null    object
#  4   subject   130 non-null    object
#  5   sender    130 non-null    object
#  6   from      130 non-null    object
#  7   date      130 non-null    object
#  8   to        130 non-null    object
#  9   cc        34 non-null     object
# dtypes: object(10)
# memory usage: 10.3+ KB

# %%
df.head()
# Out:
#                  id          threadId  \
# 0  18ccb4b4834eb5b6  18ccb4b4834eb5b6
# 1  18cd5856260e40c0  18cd5856260e40c0
# 2  18ce17ea9964f5ae  18ce17ea9964f5ae
# 3  18ce17a26e3408b9  18ce17a26e3408b9
# 4  18ce17a260f992d1  18ce17a260f992d1
#
#                                              snippet  \
# 0  ## - Não escreva abaixo dessa linha - ## Olá, ...
# 1  Prezados, A Google disponibilizou a versão 120...
# 2  Host: heitor [] Problema: Swap Memory Pages/s ...
# 3  Problem started at 22:11:55 on 2024.01.06 Prob...
# 4  Host: heitor [] Problema: Swap Memory Pages/s ...
#
#                                                 body  \
# 0   ## - Não escreva abaixo dessa linha - ## \r\n...
# 1  Prezados,\nA Google disponibilizou a versão 12...
# 2  Host: heitor []\r\nProblema: Swap Memory Pages...
# 3  Problem started at 22:11:55 on 2024.01.06\r\nP...
# 4  Host: heitor []\r\nProblema: Swap Memory Pages...
#
#                                              subject  \
# 0  =?UTF-8?q?Resolvido:_SUPORTE_T=C3=89CNICO_-_CO...
# 1  =?utf-8?B?Tm92YSB2ZXJzw6NvIGRvIG5hdmVnYWRvciBH...
# 2  [ZABBIX] [Average]:heitor Swap Memory Pages/s ...
# 3  Problem: Swap Memory Pages/s acima de 1000 por 5m
# 4  [ZABBIX] [Average]:heitor Swap Memory Pages/s ...
#
#                                               sender  \
# 0  =?UTF-8?Q?=27Licita=C3=A7=C3=B5es_Soluti=27_vi...
# 1            Atualizar_Google_Chrome_MSI@trt4.jus.br
# 2                               <zabbix@trt4.jus.br>
# 3                               <zabbix@trt4.jus.br>
# 4                               <zabbix@trt4.jus.br>
#
#                                                 from  \
# 0  =?UTF-8?Q?=27Licita=C3=A7=C3=B5es_Soluti=27_vi...
# 1            Atualizar_Google_Chrome_MSI@trt4.jus.br
# 2                               <zabbix@trt4.jus.br>
# 3                               <zabbix@trt4.jus.br>
# 4                               <zabbix@trt4.jus.br>
#
#                               date                             to  \
# 0  Tue, 02 Jan 2024 17:49:15 +0000             cracha@trt4.jus.br
# 1        4 Jan 2024 14:28:52 -0300    setic.dim-lista@trt4.jus.br
# 2  Sat, 06 Jan 2024 22:16:58 -0300  <setic.dim-lista@trt4.jus.br>
# 3  Sat, 06 Jan 2024 22:12:04 -0300  <setic.dim-lista@trt4.jus.br>
# 4  Sat, 06 Jan 2024 22:12:03 -0300  <setic.dim-lista@trt4.jus.br>
#
#                                                   cc
# 0  denilson@trt4.jus.br, jeferson.ramalho@trt4.ju...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
df['threadId'].value_counts()
# Out:
# threadId
# 18cff0b946f3a4d4    11
# 18b3d54feeab8965     5
# 18cf8f88378215c7     4
# 18cfdfec3fb42019     3
# 18cea701d4e65bf3     3
#                     ..
# 18cee460368e610c     1
# 18cee5c5bffb3865     1
# 18ceea1e26cf28a1     1
# 18ceea34dfd8b046     1
# 18d1d22d8c2550ca     1
# Name: count, Length: 93, dtype: int64

# %%
df['body_token_count'] = df['body'].apply(lambda row: len(str(row).split()) )

# %%
df.describe()
# Out:
#        body_token_count
# count        130.000000
# mean         610.738462
# std         1942.527577
# min            1.000000
# 25%           75.000000
# 50%          106.000000
# 75%          244.500000
# max        11580.000000

# %%
df.isna().sum()
# Out:
# id                   0
# threadId             0
# snippet              0
# body                20
# subject              0
# sender               0
# from                 0
# date                 0
# to                   0
# cc                  96
# body_token_count     0
# dtype: int64

# %%
df_2 = df.loc[ ~df['body'].isna() ]
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 110 entries, 0 to 129
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                110 non-null    object
#  1   threadId          110 non-null    object
#  2   snippet           110 non-null    object
#  3   body              110 non-null    object
#  4   subject           110 non-null    object
#  5   sender            110 non-null    object
#  6   from              110 non-null    object
#  7   date              110 non-null    object
#  8   to                110 non-null    object
#  9   cc                34 non-null     object
#  10  body_token_count  110 non-null    int64
# dtypes: int64(1), object(10)
# memory usage: 10.3+ KB

# %%
df_2.isna().sum()
# Out:
# id                   0
# threadId             0
# snippet              0
# body                 0
# subject              0
# sender               0
# from                 0
# date                 0
# to                   0
# cc                  76
# body_token_count     0
# dtype: int64

# %%
df_2.describe()
# Out:
#        body_token_count
# count        110.000000
# mean         721.600000
# std         2094.078099
# min           55.000000
# 25%           91.500000
# 50%          117.500000
# 75%          306.500000
# max        11580.000000

# %%
print( df_2.loc[ df_2['body_token_count'] < 60, 'body' ].iloc[0] )
# Out:
# Problem started at 14:15:09 on 2024.01.10
# Problem name: Ping
# Host: wyntech-roteador.trt4.gov.br
# Severity: Average
# Operational data: Down (0)
# Original problem ID: 3193972975
#
# --
# You received this message because you are subscribed to the Google Groups "SETIC-DIM- Divisao de Microinformatica" group.
# To unsubscribe from this group and stop receiving emails from it, send an email to setic.dim-lista+unsubscribe@trt4.jus.br.

# %%
len( df_2 [ df_2['body'].str.contains('Problem name: Ping') ] )
# Out:
# 4

# %%
df_2 [ df_2['body'].str.contains('Problem name: Ping') ]
# Out:
#                    id          threadId  \
# 44   18cf45f22c46c842  18cf2b900c7554b1
# 47   18cf3b69c815bf5c  18cf2b900c7554b1
# 49   18cf2b900c7554b1  18cf2b900c7554b1
# 124  18d14e6b485116ce  18d14e6b485116ce
#
#                                                snippet  \
# 44   Problem started at 14:15:09 on 2024.01.10 Prob...
# 47   Problem started at 11:11:09 on 2024.01.10 Prob...
# 49   Problem started at 06:34:09 on 2024.01.10 Prob...
# 124  Problem started at 21:51:09 on 2024.01.16 Prob...
#
#                                                   body        subject  \
# 44   Problem started at 14:15:09 on 2024.01.10\r\nP...  Problem: Ping
# 47   Problem started at 11:11:09 on 2024.01.10\r\nP...  Problem: Ping
# 49   Problem started at 06:34:09 on 2024.01.10\r\nP...  Problem: Ping
# 124  Problem started at 21:51:09 on 2024.01.16\r\nP...  Problem: Ping
#
#                    sender                  from  \
# 44   <zabbix@trt4.jus.br>  <zabbix@trt4.jus.br>
# 47   <zabbix@trt4.jus.br>  <zabbix@trt4.jus.br>
# 49   <zabbix@trt4.jus.br>  <zabbix@trt4.jus.br>
# 124  <zabbix@trt4.jus.br>  <zabbix@trt4.jus.br>
#
#                                 date                             to   cc  \
# 44   Wed, 10 Jan 2024 14:15:20 -0300  <setic.dim-lista@trt4.jus.br>  NaN
# 47   Wed, 10 Jan 2024 11:11:15 -0300  <setic.dim-lista@trt4.jus.br>  NaN
# 49   Wed, 10 Jan 2024 06:34:14 -0300  <setic.dim-lista@trt4.jus.br>  NaN
# 124  Tue, 16 Jan 2024 21:51:15 -0300  <setic.dim-lista@trt4.jus.br>  NaN
#
#      body_token_count
# 44                 55
# 47                 55
# 49                 55
# 124                55

# %%
df3 = df_2[ ~df_2['sender'].str.contains('zabbix@trt4.jus.br') ]
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 89 entries, 0 to 129
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                89 non-null     object
#  1   threadId          89 non-null     object
#  2   snippet           89 non-null     object
#  3   body              89 non-null     object
#  4   subject           89 non-null     object
#  5   sender            89 non-null     object
#  6   from              89 non-null     object
#  7   date              89 non-null     object
#  8   to                89 non-null     object
#  9   cc                34 non-null     object
#  10  body_token_count  89 non-null     int64
# dtypes: int64(1), object(10)
# memory usage: 8.3+ KB

# %%
import random

i = random.randint(0, len(df))

print( f'index: {i}')
print()

print( df3.loc[i, 'body'] )
# Out:
# index: 130
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /workspaces/agent_email_kb/.venv/lib/python3.10/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:2606, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:2630, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 130
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 8
#       5 print( f'index: {i}')
#       6 print()
# ----> 8 print( df3.loc[i, 'body'] )
#
# File /workspaces/agent_email_kb/.venv/lib/python3.10/site-packages/pandas/core/indexing.py:1183, in _LocationIndexer.__getitem__(self, key)
#    1181     key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#    1182     if self._is_scalar_access(key):
# -> 1183         return self.obj._get_value(*key, takeable=self._takeable)
#    1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#
# File /workspaces/agent_email_kb/.venv/lib/python3.10/site-packages/pandas/core/frame.py:4221, in DataFrame._get_value(self, index, col, takeable)
#    4215 engine = self.index._engine
#    4217 if not isinstance(self.index, MultiIndex):
#    4218     # CategoricalIndex: Trying to use the engine fastpath may give incorrect
#    4219     #  results if our categories are integers that dont match our codes
#    4220     # IntervalIndex: IntervalTree has no get_loc
# -> 4221     row = self.index.get_loc(index)
#    4222     return series._values[row]
#    4224 # For MultiIndex going through engine effectively restricts us to
#    4225 #  same-length tuples; see test_get_set_value_no_partial_indexing
#
# File /workspaces/agent_email_kb/.venv/lib/python3.10/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 130

# %%
df3.loc[104, :]
# df3.iloc[104,:]
# Out:
# id                                                   18d0d109e0295f75
# threadId                                             18cff0b946f3a4d4
# snippet             Agora que entendi, o problema que refere, não ...
# body                Agora que entendi, o problema  que refere, não...
# subject             =?UTF-8?Q?Re=3A_Problema_no_Oracle_de_S=C3=A3o...
# sender                     Paulo Ricardo Ritter <pritter@trt4.jus.br>
# from                       Paulo Ricardo Ritter <pritter@trt4.jus.br>
# date                                  Mon, 15 Jan 2024 09:19:39 -0300
# to                  Felipe dos Santos Giacomel <felipe.giacomel@tr...
# cc                  Ana Lucia Moreira <ana.moreira@trt4.jus.br>, \...
# body_token_count                                                  796
# Name: 104, dtype: object

# %%
df_thread = df3[ df3['threadId'] == '18cff0b946f3a4d4' ]
df_thread.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11 entries, 70 to 105
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                11 non-null     object
#  1   threadId          11 non-null     object
#  2   snippet           11 non-null     object
#  3   body              11 non-null     object
#  4   subject           11 non-null     object
#  5   sender            11 non-null     object
#  6   from              11 non-null     object
#  7   date              11 non-null     object
#  8   to                11 non-null     object
#  9   cc                11 non-null     object
#  10  body_token_count  11 non-null     int64
# dtypes: int64(1), object(10)
# memory usage: 1.0+ KB

# %%
df_thread.loc[:, ['threadId', 'body', 'from', 'date' ]].to_csv('thread_18cff0b946f3a4d4.csv')

# %%
print( df3.loc[70, 'body'] )
# Out:
# Vamos atualizar. Obrigado!
#
#
# Atenciosamente,
#
# Felipe Giacomel
# Divisão de Microinformática
# TRT4 - Secretaria de Tecnologia da Informação e Comunicações
#
#
# Em sex., 12 de jan. de 2024 às 17:35, Evandro Bassanesi <
# evandro.bassanesi@trt4.jus.br> escreveu:
#
# > Felipe,
# >
# > Este está desatualizado. O banco de São Leopoldo foi migrado para VMware.
# > Sugiro atualizar com o mais recente que está na rede.
# >
# > Evandro
# >
# > Em sex., 12 de jan. de 2024 às 17:29, Felipe dos Santos Giacomel <
# > felipe.giacomel@trt4.jus.br> escreveu:
# >
# >> Obrigado, Edson.
# >>
# >> Em anexo o tnsnames do servidor que deu esse problema. Me parece ser a
# >> versão atualizada. Pode verificar?
# >>
# >>
# >> Atenciosamente,
# >>
# >> Felipe Giacomel
# >> Divisão de Microinformática
# >> TRT4 - Secretaria de Tecnologia da Informação e Comunicações
# >>
# >>
# >> Em sex., 12 de jan. de 2024 às 17:09, Edson Elnei Lehr
# >> escreveu:
# >>
# >>> Parece ser de tnsnames.ora desatualizado na estação de trabalho onde o
# >>> erro ocorre. Eu acessei normalmente esse banco de dados e confirmei que o
# >>> listener está no ar.
# >>>
# >>> At.te,
# >>> *-----------*
# >>> *Edson Lehr*
# >>> ((51)3255-2491
# >>> * elehr@trt4.jus.br
# >>> DIBD/SETIC/TRT4
# >>>
# >>>
# >>>
# >>> Em sex., 12 de jan. de 2024 às 16:29, Edson Elnei Lehr <
# >>> elehr@trt4.jus.br> escreveu:
# >>>
# >>>> Copiando para o e-mail correto da DIBD.
# >>>>
# >>>> At.te,
# >>>> *-----------*
# >>>> *Edson Lehr*
# >>>> ((51)3255-2491
# >>>> * elehr@trt4.jus.br
# >>>> DIBD/SETIC/TRT4
# >>>>
# >>>>
# >>>>
# >>>> Em sex., 12 de jan. de 2024 às 15:59, Felipe dos Santos Giacomel <
# >>>> felipe.giacomel@trt4.jus.br> escreveu:
# >>>>
# >>>>> Prezada DGBD, boa tarde!
# >>>>>
# >>>>> Estamos com erro ao fazer operações na base do Infor de São Leopoldo.
# >>>>> Podem dar uma olhada, por favor?
# >>>>>
# >>>>>
# >>>>> [2024-01-12 11:41:18] Falha ao conectar … base do inFOR de SÆo
# >>>>>> Leopoldo 1¦ VT (SAOLEO.WORLD) com o usu rio inforadm: Exception calling
# >>>>>> "Open" with "0" argument(s): "ORA-12541: TNS: nÆo h  listener"
# >>>>>
# >>>>>
# >>>>>
# >>>>>
# >>>>> Atenciosamente,
# >>>>>
# >>>>> Felipe Giacomel
# >>>>> Divisão de Microinformática
# >>>>> TRT4 - Secretaria de Tecnologia da Informação e Comunicações
# >>>>>
# >>>> --
# >> Você recebeu essa mensagem porque está inscrito no grupo "SETIC - Divisão
# >> de Banco de Dados e Servidores de Aplicação" dos Grupos do Google.
# >> Para cancelar inscrição nesse grupo e parar de receber e-mails dele,
# >> envie um e-mail para setic.dibd-lista+unsubscribe@trt4.jus.br.
# >>
# >
# >
# > --
# >
# > *Evandro Bassanesi*
# > SGBD/SETIC
# > TRT 4ª Região
# > 51 3255 2491
# >
#
# --
# You received this message because you are subscribed to the Google Groups "SETIC-DIM- Divisao de Microinformatica" group.
# To unsubscribe from this group and stop receiving emails from it, send an email to setic.dim-lista+unsubscribe@trt4.jus.br.

# %%
print( df3.loc[74, 'body'] )
# Out:
# Parece ser de tnsnames.ora desatualizado na estação de trabalho onde o erro
# ocorre. Eu acessei normalmente esse banco de dados e confirmei que o
# listener está no ar.
#
# At.te,
# *-----------*
# *Edson Lehr*
# ((51)3255-2491
# * elehr@trt4.jus.br
# DIBD/SETIC/TRT4
#
#
#
# Em sex., 12 de jan. de 2024 às 16:29, Edson Elnei Lehr
# escreveu:
#
# > Copiando para o e-mail correto da DIBD.
# >
# > At.te,
# > *-----------*
# > *Edson Lehr*
# > ((51)3255-2491
# > * elehr@trt4.jus.br
# > DIBD/SETIC/TRT4
# >
# >
# >
# > Em sex., 12 de jan. de 2024 às 15:59, Felipe dos Santos Giacomel <
# > felipe.giacomel@trt4.jus.br> escreveu:
# >
# >> Prezada DGBD, boa tarde!
# >>
# >> Estamos com erro ao fazer operações na base do Infor de São Leopoldo.
# >> Podem dar uma olhada, por favor?
# >>
# >>
# >> [2024-01-12 11:41:18] Falha ao conectar … base do inFOR de SÆo Leopoldo
# >>> 1¦ VT (SAOLEO.WORLD) com o usu rio inforadm: Exception calling "Open" with
# >>> "0" argument(s): "ORA-12541: TNS: nÆo h  listener"
# >>
# >>
# >>
# >>
# >> Atenciosamente,
# >>
# >> Felipe Giacomel
# >> Divisão de Microinformática
# >> TRT4 - Secretaria de Tecnologia da Informação e Comunicações
# >>
# >
#
# --
# You received this message because you are subscribed to the Google Groups "SETIC-DIM- Divisao de Microinformatica" group.
# To unsubscribe from this group and stop receiving emails from it, send an email to setic.dim-lista+unsubscribe@trt4.jus.br.

# %%
print( df3.loc[100, 'body'] )
# Out:
# Obrigado, Paulo!
#
# Se não houver objeção técnica, sugiro alterar a GPO para ser aplicada
# também no contexto *trt4.gov.br/infraestrutura/DIM/MARKVISION
# *.
#
#
# Atenciosamente,
#
# Felipe Giacomel
# Divisão de Microinformática
# TRT4 - Secretaria de Tecnologia da Informação e Comunicações
#
#
# Em seg., 15 de jan. de 2024 às 11:05, Francisco Flesch <
# francisco.flesch@trt4.jus.br> escreveu:
#
# > Eu troquei o TNSnames na última vez que deu problema na Agenda SAT.
# > Descobri que não estava substituindo pela GPO e fiz manualmente.
# > Como o email do Felipe foi enviado após o fim do meu expediente, só vi
# > esse email hoje.
# >
# > Em seg., 15 de jan. de 2024 às 10:18, Paulo Ricardo Ritter <
# > pritter@trt4.jus.br> escreveu:
# >
# >>
# >>
# >> A GPO de atualização do TNSnames (desktop-all-oracle) nunca rodou no
# >> MarkVision, porque a estação não  está no escopo da aplicação da GPO
# >>
# >> *trt4.gov.br/infraestrutura/DIM/MARKVISION
# >> *
# >>
# >>
# >>
# >> [image: image.png]
# >>
# >> [image: image.png]
# >>
# >>
# >>
# >>
# >>
# >>
# >> Em seg., 15 de jan. de 2024 às 08:58, Paulo Ricardo Ritter <
# >> pritter@trt4.jus.br> escreveu:
# >>
# >>>
# >>> Felipe, isso não ocorre no servidor do Markvision. O  arquivo atualizado
# >>> do TNSnames  fica no servidor  Heitor, e  todas as estações do TRT têm
# >>> acesso de leitura.  GPO encarrega de realizar a cópia entre o servidor
# >>> Heitor para as estações.
# >>>
# >>> Estou acessando as estações que estão ligadas neste momento  em Sleo e
# >>> até agora não encontrei uma que não atualizou o TNSname para versão de
# >>> 06/12/2023 e uma tenho capturando para testar.a GPO
# >>>
# >>> Tem algum chamado sobre este problema ou hosts de estações com problema
# >>> no Infor? Pode ser problema isolado de algumas estações que estão parado ou
# >>> retornaram para a VT
# >>>
# >>>
# >>> [image: image.png]
# >>>
# >>>
# >>> Em sex., 12 de jan. de 2024 às 17:48, Felipe dos Santos Giacomel <
# >>> felipe.giacomel@trt4.jus.br> escreveu:
# >>>
# >>>> Paulo/Luiz de segunda, bom dia!
# >>>>
# >>>> Por favor, verifiquem por que o Markvision não rodou a GPO que atualiza
# >>>> o TNSNames e atualizem o mesmo lá.
# >>>>
# >>>>
# >>>> Atenciosamente,
# >>>>
# >>>> Felipe Giacomel
# >>>> Divisão de Microinformática
# >>>> TRT4 - Secretaria de Tecnologia da Informação e Comunicações
# >>>>
# >>>>
# >>>> Em sex., 12 de jan. de 2024 às 17:46, Felipe dos Santos Giacomel <
# >>>> felipe.giacomel@trt4.jus.br> escreveu:
# >>>>
# >>>>> Vamos atualizar. Obrigado!
# >>>>>
# >>>>>
# >>>>> Atenciosamente,
# >>>>>
# >>>>> Felipe Giacomel
# >>>>> Divisão de Microinformática
# >>>>> TRT4 - Secretaria de Tecnologia da Informação e Comunicações
# >>>>>
# >>>>>
# >>>>> Em sex., 12 de jan. de 2024 às 17:35, Evandro Bassanesi <
# >>>>> evandro.bassanesi@trt4.jus.br> escreveu:
# >>>>>
# >>>>>> Felipe,
# >>>>>>
# >>>>>> Este está desatualizado. O banco de São Leopoldo foi migrado para
# >>>>>> VMware. Sugiro atualizar com o mais recente que está na rede.
# >>>>>>
# >>>>>> Evandro
# >>>>>>
# >>>>>> Em sex., 12 de jan. de 2024 às 17:29, Felipe dos Santos Giacomel <
# >>>>>> felipe.giacomel@trt4.jus.br> escreveu:
# >>>>>>
# >>>>>>> Obrigado, Edson.
# >>>>>>>
# >>>>>>> Em anexo o tnsnames do servidor que deu esse problema. Me parece ser
# >>>>>>> a versão atualizada. Pode verificar?
# >>>>>>>
# >>>>>>>
# >>>>>>> Atenciosamente,
# >>>>>>>
# >>>>>>> Felipe Giacomel
# >>>>>>> Divisão de Microinformática
# >>>>>>> TRT4 - Secretaria de Tecnologia da Informação e Comunicações
# >>>>>>>
# >>>>>>>
# >>>>>>> Em sex., 12 de jan. de 2024 às 17:09, Edson Elnei Lehr <
# >>>>>>> elehr@trt4.jus.br> escreveu:
# >>>>>>>
# >>>>>>>> Parece ser de tnsnames.ora desatualizado na estação de trabalho
# >>>>>>>> onde o erro ocorre. Eu acessei normalmente esse banco de dados e confirmei
# >>>>>>>> que o listener está no ar.
# >>>>>>>>
# >>>>>>>> At.te,
# >>>>>>>> *-----------*
# >>>>>>>> *Edson Lehr*
# >>>>>>>> ((51)3255-2491
# >>>>>>>> * elehr@trt4.jus.br
# >>>>>>>> DIBD/SETIC/TRT4
# >>>>>>>>
# >>>>>>>>
# >>>>>>>>
# >>>>>>>> Em sex., 12 de jan. de 2024 às 16:29, Edson Elnei Lehr <
# >>>>>>>> elehr@trt4.jus.br> escreveu:
# >>>>>>>>
# >>>>>>>>> Copiando para o e-mail correto da DIBD.
# >>>>>>>>>
# >>>>>>>>> At.te,
# >>>>>>>>> *-----------*
# >>>>>>>>> *Edson Lehr*
# >>>>>>>>> ((51)3255-2491
# >>>>>>>>> * elehr@trt4.jus.br
# >>>>>>>>> DIBD/SETIC/TRT4
# >>>>>>>>>
# >>>>>>>>>
# >>>>>>>>>
# >>>>>>>>> Em sex., 12 de jan. de 2024 às 15:59, Felipe dos Santos Giacomel <
# >>>>>>>>> felipe.giacomel@trt4.jus.br> escreveu:
# >>>>>>>>>
# >>>>>>>>>> Prezada DGBD, boa tarde!
# >>>>>>>>>>
# >>>>>>>>>> Estamos com erro ao fazer operações na base do Infor de São
# >>>>>>>>>> Leopoldo. Podem dar uma olhada, por favor?
# >>>>>>>>>>
# >>>>>>>>>>
# >>>>>>>>>> [2024-01-12 11:41:18] Falha ao conectar … base do inFOR de SÆo
# >>>>>>>>>>> Leopoldo 1¦ VT (SAOLEO.WORLD) com o usu rio inforadm: Exception calling
# >>>>>>>>>>> "Open" with "0" argument(s): "ORA-12541: TNS: nÆo h  listener"
# >>>>>>>>>>
# >>>>>>>>>>
# >>>>>>>>>>
# >>>>>>>>>>
# >>>>>>>>>> Atenciosamente,
# >>>>>>>>>>
# >>>>>>>>>> Felipe Giacomel
# >>>>>>>>>> Divisão de Microinformática
# >>>>>>>>>> TRT4 - Secretaria de Tecnologia da Informação e Comunicações
# >>>>>>>>>>
# >>>>>>>>> --
# >>>>>>> Você recebeu essa mensagem porque está inscrito no grupo "SETIC -
# >>>>>>> Divisão de Banco de Dados e Servidores de Aplicação" dos Grupos do Google.
# >>>>>>> Para cancelar inscrição nesse grupo e parar de receber e-mails dele,
# >>>>>>> envie um e-mail para setic.dibd-lista+unsubscribe@trt4.jus.br.
# >>>>>>>
# >>>>>>
# >>>>>>
# >>>>>> --
# >>>>>>
# >>>>>> *Evandro Bassanesi*
# >>>>>> SGBD/SETIC
# >>>>>> TRT 4ª Região
# >>>>>> 51 3255 2491
# >>>>>>
# >>>>>
# >>>
# >>> --
# >>> Respeitosamente,
# >>> ______________________________________________
# >>> Paulo Ricardo Ritter - pritter@trt4.jus.br
# >>> Divisão de Microinformática
# >>> Secretaria de Tecnologia da Informação e Comunicações
# >>> Tribunal Regional do Trabalho da 4ª Região
# >>>
# >>>
# >>
# >> --
# >> Respeitosamente,
# >> ______________________________________________
# >> Paulo Ricardo Ritter - pritter@trt4.jus.br
# >> Divisão de Microinformática
# >> Secretaria de Tecnologia da Informação e Comunicações
# >> Tribunal Regional do Trabalho da 4ª Região
# >>
# >> --
# >> You received this message because you are subscribed to the Google Groups
# >> "SETIC-DIM- Divisao de Microinformatica" group.
# >> To unsubscribe from this group and stop receiving emails from it, send an
# >> email to setic.dim-lista+unsubscribe@trt4.jus.br.
# >>
# >
# >
# > --
# > Atenciosamente,
# > Francisco Flesch
# >
# > Tribunal Regional do Trabalho da 4ª Região - TRT4
# > Secretaria de Tecnologia da Informação e Comunicações
# > Divisão de Microinformática
# >
#
# --
# You received this message because you are subscribed to the Google Groups "SETIC-DIM- Divisao de Microinformatica" group.
# To unsubscribe from this group and stop receiving emails from it, send an email to setic.dim-lista+unsubscribe@trt4.jus.br.

# %%
import re

def extract_latest_email_content(email_text):
    # Regular expression pattern to match the start of a previous email in the thread
    pattern = re.compile(
        r"(^On .{1,1000}?\n.{0,1000}?>|^Em .{1,1000}?\n.{0,1000}?>|^De .{1,1000}?\n.{0,1000}?>|^From .{1,1000}?\n.{0,1000}?>)",
        re.MULTILINE | re.DOTALL
    )
    
    # Split the email text based on the pattern
    parts = re.split(pattern, email_text)
    
    # The latest email content is the first part before any split
    latest_email_content = parts[0].strip()
    
    return latest_email_content

# Example emails
email1 = """
Eu troquei o TNSnames na última vez que deu problema na Agenda SAT.
Descobri que não estava substituindo pela GPO e fiz manualmente.
Como o email do Felipe foi enviado após o fim do meu expediente, só vi esse
email hoje.

Em seg., 15 de jan. de 2024 às 10:18, Paulo Ricardo Ritter <
pritter@trt4.jus.br> escreveu:

>

A GPO de atualização do TNSnames (desktop-all-oracle) nunca rodou no
MarkVision, porque a estação não  está no escopo da aplicação da GPO

*trt4.gov.br/infraestrutura/DIM/MARKVISION
*
"""

email2 = """
Yes that is fine, I will email you in the morning.

On Fri, Nov 16, 2012 at 1:48 PM, Zapier <contact@zapier.com> wrote:

> Our support team just commented on your open Ticket:
> "Hi Royce, can we chat in the morning about your question?"
"""

# Extract the latest email content
print(extract_latest_email_content(email1))
print("------")
print(extract_latest_email_content(email2))
# Out:
# Eu troquei o TNSnames na última vez que deu problema na Agenda SAT.
# Descobri que não estava substituindo pela GPO e fiz manualmente.
# Como o email do Felipe foi enviado após o fim do meu expediente, só vi esse
# email hoje.
# ------
# Yes that is fine, I will email you in the morning.

# %%
df_thread.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11 entries, 70 to 105
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                11 non-null     object
#  1   threadId          11 non-null     object
#  2   snippet           11 non-null     object
#  3   body              11 non-null     object
#  4   subject           11 non-null     object
#  5   sender            11 non-null     object
#  6   from              11 non-null     object
#  7   date              11 non-null     object
#  8   to                11 non-null     object
#  9   cc                11 non-null     object
#  10  body_token_count  11 non-null     int64
# dtypes: int64(1), object(10)
# memory usage: 1.0+ KB

# %%
df_thread
# Out:
#                    id          threadId  \
# 70   18cff6d8c3ab9dff  18cff0b946f3a4d4
# 72   18cff62a8e788bc6  18cff0b946f3a4d4
# 73   18cff5dc35eaf078  18cff0b946f3a4d4
# 74   18cff4b0e561857c  18cff0b946f3a4d4
# 75   18cff26986c6a228  18cff0b946f3a4d4
# 76   18cff0b946f3a4d4  18cff0b946f3a4d4
# 100  18d0da8219fe879e  18cff0b946f3a4d4
# 101  18d0d715ce249168  18cff0b946f3a4d4
# 102  18d0d4638d227d0a  18cff0b946f3a4d4
# 104  18d0d109e0295f75  18cff0b946f3a4d4
# 105  18d0cfda3ef2a252  18cff0b946f3a4d4
#
#                                                snippet  \
# 70   Vamos atualizar. Obrigado! Atenciosamente, Fel...
# 72   Felipe, Este está desatualizado. O banco de Sã...
# 73   Obrigado, Edson. Em anexo o tnsnames do servid...
# 74   Parece ser de tnsnames.ora desatualizado na es...
# 75   Copiando para o e-mail correto da DIBD. At.te,...
# 76   Prezada DGBD, boa tarde! Estamos com erro ao f...
# 100  Obrigado, Paulo! Se não houver objeção técnica...
# 101  Eu troquei o TNSnames na última vez que deu pr...
# 102  A GPO de atualização do TNSnames (desktop-all-...
# 104  Agora que entendi, o problema que refere, não ...
# 105  Felipe, isso não ocorre no servidor do Markvis...
#
#                                                   body  \
# 70   Vamos atualizar. Obrigado!\r\n\r\n\r\nAtencios...
# 72   Felipe,\r\n\r\nEste está desatualizado. O banc...
# 73   Obrigado, Edson.\r\n\r\nEm anexo o tnsnames do...
# 74   Parece ser de tnsnames.ora desatualizado na es...
# 75   Copiando para o e-mail correto da DIBD.\r\n\r\...
# 76   Prezada DGBD, boa tarde!\r\n\r\nEstamos com er...
# 100  Obrigado, Paulo!\r\n\r\nSe não houver objeção ...
# 101  Eu troquei o TNSnames na última vez que deu pr...
# 102  A GPO de atualização do TNSnames (desktop-all-...
# 104  Agora que entendi, o problema  que refere, não...
# 105  Felipe, isso não ocorre no servidor do Markvis...
#
#                                                subject  \
# 70   =?UTF-8?Q?Re=3A_Problema_no_Oracle_de_S=C3=A3o...
# 72   =?UTF-8?Q?Re=3A_Problema_no_Oracle_de_S=C3=A3o...
# 73   =?UTF-8?Q?Re=3A_Problema_no_Oracle_de_S=C3=A3o...
# 74   =?UTF-8?Q?Re=3A_Problema_no_Oracle_de_S=C3=A3o...
# 75   =?UTF-8?Q?Re=3A_Problema_no_Oracle_de_S=C3=A3o...
# 76   =?UTF-8?Q?Problema_no_Oracle_de_S=C3=A3o_Leopo...
# 100  =?UTF-8?Q?Re=3A_Problema_no_Oracle_de_S=C3=A3o...
# 101  =?UTF-8?Q?Re=3A_Problema_no_Oracle_de_S=C3=A3o...
# 102  =?UTF-8?Q?Re=3A_Problema_no_Oracle_de_S=C3=A3o...
# 104  =?UTF-8?Q?Re=3A_Problema_no_Oracle_de_S=C3=A3o...
# 105  =?UTF-8?Q?Re=3A_Problema_no_Oracle_de_S=C3=A3o...
#
#                                                 sender  \
# 70   Felipe dos Santos Giacomel <felipe.giacomel@tr...
# 72   Evandro Bassanesi <evandro.bassanesi@trt4.jus.br>
# 73   Felipe dos Santos Giacomel <felipe.giacomel@tr...
# 74                Edson Elnei Lehr <elehr@trt4.jus.br>
# 75                Edson Elnei Lehr <elehr@trt4.jus.br>
# 76   Felipe dos Santos Giacomel <felipe.giacomel@tr...
# 100  Felipe dos Santos Giacomel <felipe.giacomel@tr...
# 101    Francisco Flesch <francisco.flesch@trt4.jus.br>
# 102         Paulo Ricardo Ritter <pritter@trt4.jus.br>
# 104         Paulo Ricardo Ritter <pritter@trt4.jus.br>
# 105         Paulo Ricardo Ritter <pritter@trt4.jus.br>
#
#                                                   from  \
# 70   Felipe dos Santos Giacomel <felipe.giacomel@tr...
# 72   Evandro Bassanesi <evandro.bassanesi@trt4.jus.br>
# 73   Felipe dos Santos Giacomel <felipe.giacomel@tr...
# 74                Edson Elnei Lehr <elehr@trt4.jus.br>
# 75                Edson Elnei Lehr <elehr@trt4.jus.br>
# 76   Felipe dos Santos Giacomel <felipe.giacomel@tr...
# 100  Felipe dos Santos Giacomel <felipe.giacomel@tr...
# 101    Francisco Flesch <francisco.flesch@trt4.jus.br>
# 102         Paulo Ricardo Ritter <pritter@trt4.jus.br>
# 104         Paulo Ricardo Ritter <pritter@trt4.jus.br>
# 105         Paulo Ricardo Ritter <pritter@trt4.jus.br>
#
#                                 date  \
# 70   Fri, 12 Jan 2024 17:46:45 -0300
# 72   Fri, 12 Jan 2024 17:34:50 -0300
# 73   Fri, 12 Jan 2024 17:29:30 -0300
# 74   Fri, 12 Jan 2024 17:09:03 -0300
# 75   Fri, 12 Jan 2024 16:29:16 -0300
# 76   Fri, 12 Jan 2024 15:59:44 -0300
# 100  Mon, 15 Jan 2024 12:05:23 -0300
# 101  Mon, 15 Jan 2024 11:05:28 -0300
# 102  Mon, 15 Jan 2024 10:18:12 -0300
# 104  Mon, 15 Jan 2024 09:19:39 -0300
# 105  Mon, 15 Jan 2024 08:58:54 -0300
#
#                                                     to  \
# 70   Evandro Bassanesi <evandro.bassanesi@trt4.jus.br>
# 72   Felipe dos Santos Giacomel <felipe.giacomel@tr...
# 73                Edson Elnei Lehr <elehr@trt4.jus.br>
# 74   Felipe dos Santos Giacomel <felipe.giacomel@tr...
# 75   Felipe dos Santos Giacomel <felipe.giacomel@tr...
# 76   Gestores da Secao de Gerenciamento de Banco de...
# 100    Francisco Flesch <francisco.flesch@trt4.jus.br>
# 101         Paulo Ricardo Ritter <pritter@trt4.jus.br>
# 102  Felipe dos Santos Giacomel <felipe.giacomel@tr...
# 104  Felipe dos Santos Giacomel <felipe.giacomel@tr...
# 105  Felipe dos Santos Giacomel <felipe.giacomel@tr...
#
#                                                     cc  body_token_count
# 70   Edson Elnei Lehr <elehr@trt4.jus.br>, \r\n\tSE...               446
# 72   Edson Elnei Lehr <elehr@trt4.jus.br>, \r\n\tSE...               393
# 73   SETIC-DIM- Divisao de Microinformatica <setic....               281
# 74   Gestores da Secao de Gerenciamento de Banco de...               217
# 75   Gestores da Secao de Gerenciamento de Banco de...               153
# 76   SETIC-DIM- Divisao de Microinformatica <setic....               105
# 100  Paulo Ricardo Ritter <pritter@trt4.jus.br>, An...               994
# 101  Felipe dos Santos Giacomel <felipe.giacomel@tr...               928
# 102  Ana Lucia Moreira <ana.moreira@trt4.jus.br>, \...               778
# 104  Ana Lucia Moreira <ana.moreira@trt4.jus.br>, \...               796
# 105  Ana Lucia Moreira <ana.moreira@trt4.jus.br>, \...               679

# %%
# df['date'] = pd.to_datetime(df['date'], format='%a, %d %b %Y %H:%M:%S %z')
df_thread.loc[:, 'date'] = pd.to_datetime(df_thread['date'], format='mixed', utc=True)
df_thread.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11 entries, 70 to 105
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                11 non-null     object
#  1   threadId          11 non-null     object
#  2   snippet           11 non-null     object
#  3   body              11 non-null     object
#  4   subject           11 non-null     object
#  5   sender            11 non-null     object
#  6   from              11 non-null     object
#  7   date              11 non-null     object
#  8   to                11 non-null     object
#  9   cc                11 non-null     object
#  10  body_token_count  11 non-null     int64
# dtypes: int64(1), object(10)
# memory usage: 1.0+ KB

# %%
df_thread
# Out:
#                    id          threadId  \
# 70   18cff6d8c3ab9dff  18cff0b946f3a4d4
# 72   18cff62a8e788bc6  18cff0b946f3a4d4
# 73   18cff5dc35eaf078  18cff0b946f3a4d4
# 74   18cff4b0e561857c  18cff0b946f3a4d4
# 75   18cff26986c6a228  18cff0b946f3a4d4
# 76   18cff0b946f3a4d4  18cff0b946f3a4d4
# 100  18d0da8219fe879e  18cff0b946f3a4d4
# 101  18d0d715ce249168  18cff0b946f3a4d4
# 102  18d0d4638d227d0a  18cff0b946f3a4d4
# 104  18d0d109e0295f75  18cff0b946f3a4d4
# 105  18d0cfda3ef2a252  18cff0b946f3a4d4
#
#                                                snippet  \
# 70   Vamos atualizar. Obrigado! Atenciosamente, Fel...
# 72   Felipe, Este está desatualizado. O banco de Sã...
# 73   Obrigado, Edson. Em anexo o tnsnames do servid...
# 74   Parece ser de tnsnames.ora desatualizado na es...
# 75   Copiando para o e-mail correto da DIBD. At.te,...
# 76   Prezada DGBD, boa tarde! Estamos com erro ao f...
# 100  Obrigado, Paulo! Se não houver objeção técnica...
# 101  Eu troquei o TNSnames na última vez que deu pr...
# 102  A GPO de atualização do TNSnames (desktop-all-...
# 104  Agora que entendi, o problema que refere, não ...
# 105  Felipe, isso não ocorre no servidor do Markvis...
#
#                                                   body  \
# 70   Vamos atualizar. Obrigado!\r\n\r\n\r\nAtencios...
# 72   Felipe,\r\n\r\nEste está desatualizado. O banc...
# 73   Obrigado, Edson.\r\n\r\nEm anexo o tnsnames do...
# 74   Parece ser de tnsnames.ora desatualizado na es...
# 75   Copiando para o e-mail correto da DIBD.\r\n\r\...
# 76   Prezada DGBD, boa tarde!\r\n\r\nEstamos com er...
# 100  Obrigado, Paulo!\r\n\r\nSe não houver objeção ...
# 101  Eu troquei o TNSnames na última vez que deu pr...
# 102  A GPO de atualização do TNSnames (desktop-all-...
# 104  Agora que entendi, o problema  que refere, não...
# 105  Felipe, isso não ocorre no servidor do Markvis...
#
#                                                subject  \
# 70   =?UTF-8?Q?Re=3A_Problema_no_Oracle_de_S=C3=A3o...
# 72   =?UTF-8?Q?Re=3A_Problema_no_Oracle_de_S=C3=A3o...
# 73   =?UTF-8?Q?Re=3A_Problema_no_Oracle_de_S=C3=A3o...
# 74   =?UTF-8?Q?Re=3A_Problema_no_Oracle_de_S=C3=A3o...
# 75   =?UTF-8?Q?Re=3A_Problema_no_Oracle_de_S=C3=A3o...
# 76   =?UTF-8?Q?Problema_no_Oracle_de_S=C3=A3o_Leopo...
# 100  =?UTF-8?Q?Re=3A_Problema_no_Oracle_de_S=C3=A3o...
# 101  =?UTF-8?Q?Re=3A_Problema_no_Oracle_de_S=C3=A3o...
# 102  =?UTF-8?Q?Re=3A_Problema_no_Oracle_de_S=C3=A3o...
# 104  =?UTF-8?Q?Re=3A_Problema_no_Oracle_de_S=C3=A3o...
# 105  =?UTF-8?Q?Re=3A_Problema_no_Oracle_de_S=C3=A3o...
#
#                                                 sender  \
# 70   Felipe dos Santos Giacomel <felipe.giacomel@tr...
# 72   Evandro Bassanesi <evandro.bassanesi@trt4.jus.br>
# 73   Felipe dos Santos Giacomel <felipe.giacomel@tr...
# 74                Edson Elnei Lehr <elehr@trt4.jus.br>
# 75                Edson Elnei Lehr <elehr@trt4.jus.br>
# 76   Felipe dos Santos Giacomel <felipe.giacomel@tr...
# 100  Felipe dos Santos Giacomel <felipe.giacomel@tr...
# 101    Francisco Flesch <francisco.flesch@trt4.jus.br>
# 102         Paulo Ricardo Ritter <pritter@trt4.jus.br>
# 104         Paulo Ricardo Ritter <pritter@trt4.jus.br>
# 105         Paulo Ricardo Ritter <pritter@trt4.jus.br>
#
#                                                   from  \
# 70   Felipe dos Santos Giacomel <felipe.giacomel@tr...
# 72   Evandro Bassanesi <evandro.bassanesi@trt4.jus.br>
# 73   Felipe dos Santos Giacomel <felipe.giacomel@tr...
# 74                Edson Elnei Lehr <elehr@trt4.jus.br>
# 75                Edson Elnei Lehr <elehr@trt4.jus.br>
# 76   Felipe dos Santos Giacomel <felipe.giacomel@tr...
# 100  Felipe dos Santos Giacomel <felipe.giacomel@tr...
# 101    Francisco Flesch <francisco.flesch@trt4.jus.br>
# 102         Paulo Ricardo Ritter <pritter@trt4.jus.br>
# 104         Paulo Ricardo Ritter <pritter@trt4.jus.br>
# 105         Paulo Ricardo Ritter <pritter@trt4.jus.br>
#
#                           date  \
# 70   2024-01-12 20:46:45+00:00
# 72   2024-01-12 20:34:50+00:00
# 73   2024-01-12 20:29:30+00:00
# 74   2024-01-12 20:09:03+00:00
# 75   2024-01-12 19:29:16+00:00
# 76   2024-01-12 18:59:44+00:00
# 100  2024-01-15 15:05:23+00:00
# 101  2024-01-15 14:05:28+00:00
# 102  2024-01-15 13:18:12+00:00
# 104  2024-01-15 12:19:39+00:00
# 105  2024-01-15 11:58:54+00:00
#
#                                                     to  \
# 70   Evandro Bassanesi <evandro.bassanesi@trt4.jus.br>
# 72   Felipe dos Santos Giacomel <felipe.giacomel@tr...
# 73                Edson Elnei Lehr <elehr@trt4.jus.br>
# 74   Felipe dos Santos Giacomel <felipe.giacomel@tr...
# 75   Felipe dos Santos Giacomel <felipe.giacomel@tr...
# 76   Gestores da Secao de Gerenciamento de Banco de...
# 100    Francisco Flesch <francisco.flesch@trt4.jus.br>
# 101         Paulo Ricardo Ritter <pritter@trt4.jus.br>
# 102  Felipe dos Santos Giacomel <felipe.giacomel@tr...
# 104  Felipe dos Santos Giacomel <felipe.giacomel@tr...
# 105  Felipe dos Santos Giacomel <felipe.giacomel@tr...
#
#                                                     cc  body_token_count
# 70   Edson Elnei Lehr <elehr@trt4.jus.br>, \r\n\tSE...               446
# 72   Edson Elnei Lehr <elehr@trt4.jus.br>, \r\n\tSE...               393
# 73   SETIC-DIM- Divisao de Microinformatica <setic....               281
# 74   Gestores da Secao de Gerenciamento de Banco de...               217
# 75   Gestores da Secao de Gerenciamento de Banco de...               153
# 76   SETIC-DIM- Divisao de Microinformatica <setic....               105
# 100  Paulo Ricardo Ritter <pritter@trt4.jus.br>, An...               994
# 101  Felipe dos Santos Giacomel <felipe.giacomel@tr...               928
# 102  Ana Lucia Moreira <ana.moreira@trt4.jus.br>, \...               778
# 104  Ana Lucia Moreira <ana.moreira@trt4.jus.br>, \...               796
# 105  Ana Lucia Moreira <ana.moreira@trt4.jus.br>, \...               679
