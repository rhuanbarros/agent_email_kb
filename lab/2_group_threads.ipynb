# %%
import pandas as pd

# %%
df = pd.read_csv('emails.csv', index_col='Unnamed: 0')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2307 entries, 0 to 2306
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        2307 non-null   object
#  1   threadId  2307 non-null   object
#  2   snippet   2307 non-null   object
#  3   body      2194 non-null   object
#  4   subject   2307 non-null   object
#  5   sender    2307 non-null   object
# dtypes: object(6)
# memory usage: 126.2+ KB

# %%
df.head()
# Out:
#                  id          threadId  \
# 0  18ccb4b4834eb5b6  18ccb4b4834eb5b6
# 1  18cd5856260e40c0  18cd5856260e40c0
# 2  18ce17ea9964f5ae  18ce17ea9964f5ae
# 3  18ce17a26e3408b9  18ce17a26e3408b9
# 4  18ce17a260f992d1  18ce17a260f992d1
#
#                                              snippet  \
# 0  ## - Não escreva abaixo dessa linha - ## Olá, ...
# 1  Prezados, A Google disponibilizou a versão 120...
# 2  Host: heitor [] Problema: Swap Memory Pages/s ...
# 3  Problem started at 22:11:55 on 2024.01.06 Prob...
# 4  Host: heitor [] Problema: Swap Memory Pages/s ...
#
#                                                 body  \
# 0   ## - Não escreva abaixo dessa linha - ## \r\n...
# 1  Prezados,\nA Google disponibilizou a versão 12...
# 2  Host: heitor []\r\nProblema: Swap Memory Pages...
# 3  Problem started at 22:11:55 on 2024.01.06\r\nP...
# 4  Host: heitor []\r\nProblema: Swap Memory Pages...
#
#                                              subject  \
# ...

# %%
df['threadId'].value_counts()
# Out:
# threadId
# 18d6029d681da622    21
# 18ea47d9dee3a4f8    20
# 18fa091132aeaf61    20
# 18cff0b946f3a4d4    19
# 18d41642e80a65a5    18
#                     ..
# 18e337eb9d34803b     1
# 18e337888cb5738b     1
# 18e3373da59c7ea0     1
# 18e332226a67ce3e     1
# 190a6f57c81b0383     1
# Name: count, Length: 1258, dtype: int64

# %%
print( df.loc[0, 'body'] )
# Out:
#  ## - Não escreva abaixo dessa linha - ##
#
#
#     Olá, SEGESP Certificação Digital e Identificação Funcional !
#
#    O ticket Nº 958187 - (SUPORTE TÉCNICO - CONTRATO TRT4 Nº 64/2023) foi considerado como resolvido pelo agente. Você esta de acordo com a solução apresentada abaixo? Caso não esteja, basta responder este e-mail.
#
#  Atendente 4 02/01/2024 14:49 (UTC-03:00 Horário de Brasília (São Paulo)) 11
#
#   https://site.solutinet.com.br/2015/minhanovaassinatura-reloaded/imgs/left-image.gif licitacoes@soluti.com.br 4000 1807soluti.com.brhttps://site.solutinet.com.br/2015/minhanovaassinatura-reloaded/imgs/logo-soluti.png  Atendente 4 27/12/2023 13:34 (UTC-03:00 Horário de Brasília (São Paulo)) 10
#
# Prezados, boa tarde!
#
#  Gratos pelo retorno e cientes das informações. Quaisquer intercorrências, pedimos que nos comuniquem para melhor atendê-los.
#
#  Estamos à disposição.
#
#  Att.
#
# ...
